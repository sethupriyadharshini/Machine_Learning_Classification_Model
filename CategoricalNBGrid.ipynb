# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('CKD.csv')

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
indep=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]
dep=dataset['classification_yes']

# %%
from sklearn.naive_bayes import CategoricalNB

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import CategoricalNB

# Define the parameter grid
param_grid = {'alpha': [0.1, 0.5, 1.0, 2.0, 5.0]}

# Set up the GridSearchCV
grid = GridSearchCV(CategoricalNB(), param_grid, refit=True, verbose=3, n_jobs=-1, scoring='f1_weighted')

# Fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan]
#   warnings.warn(
# GridSearchCV(estimator=CategoricalNB(), n_jobs=-1,
#              param_grid={'alpha': [0.1, 0.5, 1.0, 2.0, 5.0]},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(indep)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(dep, grid_predictions)

# %%
print(cm)
# Out:
# [[150   0]
#  [  1 248]]

# %%
# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(dep, grid_predictions)

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       150
#            1       1.00      1.00      1.00       249
#
#     accuracy                           1.00       399
#    macro avg       1.00      1.00      1.00       399
# weighted avg       1.00      1.00      1.00       399

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(dep,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'alpha': 0.1}: 0.9974953761738116

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(dep,grid.predict_proba(indep)[:,1])
# Out:
# 1.0

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0       0.019319      0.002833         0.011108        0.004400         0.1
# 1       0.020522      0.003071         0.011549        0.004075         0.5
# 2       0.015582      0.003577         0.011304        0.005992         1.0
# 3       0.014147      0.001914         0.007908        0.001874         2.0
# 4       0.009873      0.002393         0.001325        0.001756         5.0
#
#            params  split0_test_score  split1_test_score  split2_test_score  \
# 0  {'alpha': 0.1}           0.962618                NaN                NaN
# 1  {'alpha': 0.5}           0.962618                NaN                NaN
# 2  {'alpha': 1.0}           0.950296                NaN                NaN
# 3  {'alpha': 2.0}           0.950296                NaN                NaN
# 4  {'alpha': 5.0}           0.950296                NaN                NaN
#
#    split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0                NaN                NaN              NaN             NaN
# 1                NaN                NaN              NaN             NaN
# 2                NaN                NaN              NaN             NaN
# 3                NaN                NaN              NaN             NaN
# 4                NaN                NaN              NaN             NaN
#
#    rank_test_score
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
